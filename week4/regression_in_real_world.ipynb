# %%
import pandas as pd

hunger = pd.read_csv('http://apps.who.int/gho/athena/data/GHO/WHOSIS_000008.csv?profile=text&filter=COUNTRY:;SEX:')

hunger = hunger[hunger['Sex'] != 'Both sexes']
# the last entry is all NaN 
hunger = hunger[hunger['Year'].notnull()]
hunger.columns = map(lambda x: x.replace(' ', '_').lower(), hunger.columns)

# %%
hunger.head()
# Out:
#                                 indicator  data_source      country     sex  year  \
# 1  Children aged <5 years underweight (%)  NLIS_312819  Afghanistan    Male  2004
# 3  Children aged <5 years underweight (%)  NLIS_312819  Afghanistan  Female  2004
# 6  Children aged <5 years underweight (%)  NLIS_312361      Albania    Male  2000
# 7  Children aged <5 years underweight (%)  NLIS_312361      Albania  Female  2000
# 8  Children aged <5 years underweight (%)  NLIS_312879      Albania  Female  2005
#
#               who_region  display_value  numeric  low  high  comments
# 1  Eastern Mediterranean           32.7     32.7  NaN   NaN       NaN
# 3  Eastern Mediterranean           33.0     33.0  NaN   NaN       NaN
# 6                 Europe           19.6     19.6  NaN   NaN       NaN
# 7                 Europe           14.2     14.2  NaN   NaN       NaN
# 8                 Europe            5.8      5.8  NaN   NaN       NaN

# %%
# emulates abline function, only possible to set basic line styles and width
def abline(intercept, gradient, *args, **kwargs):
    a = gca()
    xlim = a.get_xlim()
    ylim = a.get_ylim()
    
    if args:
        sty = args[0]
    else:
        sty = 'r'
        
    if kwargs:
        lw = kwargs['linewidth']
    else:
        lw = 5

    a.plot(xlim, [intercept + gradient * x for x in xlim], sty, linewidth=lw)
    a.set_xlim(xlim)
    a.set_ylim(ylim)

# %%
regions = hunger.groupby('who_region')

colors = {'Africa': 'k',
          'Americas': 'r',
          'Eastern Mediterranean': 'g',
          'Europe': 'b',
          'South-East Asia': 'c',
          'WHO Non Members': 'y',
          'Western Pacific': 'm'}

f, (ax1, ax2) = subplots(ncols=2)
f.set_size_inches(8, 4)

for g, v in regions:
    ax1.scatter(v['year'], v['numeric'], c=colors[g])
    ax2.scatter(0, 0, c=colors[g], label=g)
    
ax1.set_xlabel('Year')
ax1.set_ylabel('Numeric')
ax2.set_xticklabels('')
ax2.set_yticklabels('')
ax2.legend(loc='center')
f.tight_layout();

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

anova_lm(ols('year ~ who_region', hunger).fit())
# Out:
#              df        sum_sq     mean_sq         F    PR(>F)
# who_region    6    622.797291  103.799548  2.246787  0.037017
# Residual    851  39315.440471   46.199107       NaN       NaN

# %%
anova_lm(ols('numeric ~ who_region', hunger).fit())
# Out:
#              df        sum_sq       mean_sq           F         PR(>F)
# who_region    6  75042.496613  12507.082769  126.930068  1.567368e-114
# Residual    851  83853.476452     98.535225         NaN            NaN

# %%
lmRegion = ols('numeric ~ year + who_region + year * who_region', hunger).fit()
lmRegion.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                numeric   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     74.76
# Date:                Wed, 13 Feb 2013   Prob (F-statistic):          7.34e-124
# Time:                        21:15:27   Log-Likelihood:                -3147.0
# No. Observations:                 858   AIC:                             6320.
# Df Residuals:                     845   BIC:                             6382.
# Df Model:                          12
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                  732.4051    186.157      3.934      0.000       367.021  1097.790
# who_region[T.Americas]                    -444.7587    278.381     -1.598      0.110      -991.158   101.641
# who_region[T.Eastern Mediterranean]       -191.1475    308.592     -0.619      0.536      -796.844   414.548
# who_region[T.Europe]                      -634.7164    413.423     -1.535      0.125     -1446.174   176.741
# who_region[T.South-East Asia]             1168.9194    316.283      3.696      0.000       548.126  1789.713
# who_region[T.WHO Non Members]             -4.36e-06   1.69e-06     -2.583      0.010     -7.67e-06 -1.05e-06
# who_region[T.Western Pacific]             -670.4302    309.319     -2.167      0.030     -1277.554   -63.306
# year                                        -0.3551      0.093     -3.817      0.000        -0.538    -0.172
# year:who_region[T.Americas]                  0.2148      0.139      1.544      0.123        -0.058     0.488
# year:who_region[T.Eastern Mediterranean]     0.0911      0.154      0.591      0.555        -0.212     0.394
# year:who_region[T.Europe]                    0.3088      0.207      1.495      0.135        -0.097     0.714
# year:who_region[T.South-East Asia]          -0.5780      0.158     -3.656      0.000        -0.888    -0.268
# year:who_region[T.WHO Non Members]          -0.0087      0.003     -2.580      0.010        -0.015    -0.002
# year:who_region[T.Western Pacific]           0.3336      0.155      2.158      0.031         0.030     0.637
# ==============================================================================
# Omnibus:                       49.503   Durbin-Watson:                   0.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.017
# Skew:                           0.593   Prob(JB):                     4.16e-13
# Kurtosis:                       3.434   Cond. No.                          nan
# ==============================================================================
#
# The smallest eigenvalue is -4.83e-08. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
for g, v in regions:
    scatter(v['year'], v['numeric'], c=colors[g])

intercept = lmRegion.params['Intercept']
se_asia = lmRegion.params['who_region[T.South-East Asia]']
year = lmRegion.params['year']
year_se_asia = lmRegion.params['year:who_region[T.South-East Asia]']

abline(intercept + se_asia, year + year_se_asia, 'c', linewidth=3)

# %% [markdown]
# ### Right-skewed data

# %%
incomeData = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)

# %%
# last row is all NaNs
incomeData = incomeData.drop(32561)
incomeData.tail()
# Out:
#        0              1       2            3   4                    5   \
# 32556  27        Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40        Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58        Private  151910      HS-grad   9              Widowed
# 32559  22        Private  201490      HS-grad   9        Never-married
# 32560  52   Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                        6           7       8        9      10  11  12              13  \
# 32556        Tech-support        Wife   White   Female      0   0  38   United-States
# 32557   Machine-op-inspct     Husband   White     Male      0   0  40   United-States
# 32558        Adm-clerical   Unmarried   White   Female      0   0  40   United-States
# 32559        Adm-clerical   Own-child   White     Male      0   0  20   United-States
# 32560     Exec-managerial        Wife   White   Female  15024   0  40   United-States
#
#            14
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K

# %%
income = incomeData.ix[:,2]
age = incomeData.ix[:,0]

f, (ax1, ax2, ax3, ax4) = subplots(ncols=4)

ax1.scatter(age, income, marker='.')

ax2.hist(income, range=(income.min(), income.max()), bins=100)

log_income = income.apply(lambda x: np.log(x + 1))
ax3.hist(log_income, range=(log_income.min(), log_income.max()), bins=200)

ax4.scatter(age, log_income, marker='.')

f.set_size_inches(10, 5)
f.tight_layout();

# %% [markdown]
# ### Outlier

# %%
import numpy as np

np.random.seed(34568)
xVals = np.random.standard_cauchy(size=50)
hist(xVals);

# %%
# add Tim Cook
age = np.append(np.array(age), 52)
income = np.append(np.array(income), 378e6)

scatter(age, income, marker='.');

# %%
from statsmodels.formula.api import rlm

# robust linear model
# ?rlm

# %% [markdown]
# ### Variance changes

# %%
bupaData = pd.read_csv('ftp://ftp.ics.uci.edu/pub/machine-learning-databases/liver-disorders/bupa.data', header=None)

# %%
ggt = bupaData.ix[:,4]
aat = bupaData.ix[:,2]

plot(np.log(ggt), aat, 'ob')
xlabel('log(ggt)')
ylabel('aat');

# %%
lm1 = ols('aat ~ np.log(ggt)', pd.DataFrame({'aat' : aat, 'ggt' : ggt})).fit()

plot(ggt.apply(np.log), lm1.resid, 'ob')
xlabel('log(ggt)')
ylabel('lm1.resid');
